# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\HP\Documents\Book9.csv")
df
# Out:
#     Mileage  Age(yrs)  Price(US$)
# 0     69000         6       18000
# 1     35000         3       34000
# 2     57000         5       26100
# 3     22500         2       40000
# 4     46000         4       31500
# 5     59000         5       26750
# 6     52000         5       32000
# 7     72000         6       19300
# 8     91000         8       12000
# 9     67000         6       22000
# 10    83000         7       18700
# 11    79000         7       19500
# 12    59000         5       26000
# 13    58780         4       27500
# 14    82450         7       19400
# 15    25400         3       35000
# 16    28000         2       35500
# 17    69000         5       19700
# 18    87600         8       12800
# 19    52000         5       28200

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.scatter(df['Mileage'],df['Price(US$)'])

# %%
plt.scatter(df['Mileage'],df['Age(yrs)'])

# %%
X=df[['Mileage','Age(yrs)']]

# %%
y=df['Price(US$)']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3)

# %%
X_train
# Out:
#     Mileage  Age(yrs)
# 10    83000         7
# 7     72000         6
# 2     57000         5
# 14    82450         7
# 19    52000         5
# 9     67000         6
# 18    87600         8
# 5     59000         5
# 1     35000         3
# 17    69000         5
# 11    79000         7
# 13    58780         4
# 15    25400         3
# 16    28000         2

# %%
X_test
# Out:
#     Mileage  Age(yrs)
# 3     22500         2
# 4     46000         4
# 12    59000         5
# 0     69000         6
# 6     52000         5
# 8     91000         8

# %%
len(X_train)
# Out:
# 14

# %%
len(X_test)
# Out:
# 6

# %%
from sklearn.linear_model import LinearRegression
clf=LinearRegression()
clf.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
clf.coef_
# Out:
# array([-2.73279020e-01, -7.33799824e+02])

# %%
clf.intercept_
# Out:
# np.float64(45123.843121219135)

# %%
clf.predict(X_test)
# Out:
# array([37507.46551614, 29617.8088907 , 25331.38180254, 21864.79177545,
#        27244.33494502, 14385.05368054])

# %%
clf.score(X_test,y_test)
# Out:
# 0.8972644899429595

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=10)

# %%
X_test
# Out:
#     Mileage  Age(yrs)
# 7     72000         6
# 10    83000         7
# 5     59000         5
# 6     52000         5
# 3     22500         2
# 18    87600         8

# %%
X_train
# Out:
#     Mileage  Age(yrs)
# 13    58780         4
# 2     57000         5
# 14    82450         7
# 8     91000         8
# 17    69000         5
# 16    28000         2
# 19    52000         5
# 12    59000         5
# 11    79000         7
# 1     35000         3
# 0     69000         6
# 15    25400         3
# 4     46000         4
# 9     67000         6

# %%
clf.predict(X_test)
# Out:
# array([21044.95471439, 17305.08566693, 25331.38180254, 27244.33494502,
#        37507.46551614, 15314.20234974])

# %%
clf.score(X_test,y_test)
# Out:
# 0.9153628590255939
