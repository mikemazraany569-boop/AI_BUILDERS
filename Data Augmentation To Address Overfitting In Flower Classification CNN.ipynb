# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2
import os
import PIL
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
# Out:
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\export\tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):

# %%
dataset_url = "https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz"
data_dir = tf.keras.utils.get_file('flower_photos', origin=dataset_url,  cache_dir='.', untar=True)

# %%
data_dir
# Out:
# '.\\datasets\\flower_photos'

# %%
import pathlib
data_dir = pathlib.Path(data_dir)
data_dir
# Out:
# WindowsPath('datasets/flower_photos')

# %%
from pathlib import Path
data_dir = Path("datasets/flower_photos/flower_photos")

# %%
list(data_dir.glob('*/*.jpg'))[:5]
# Out:
# [WindowsPath('datasets/flower_photos/flower_photos/daisy/100080576_f52e8ee070_n.jpg'),
#  WindowsPath('datasets/flower_photos/flower_photos/daisy/10140303196_b88d3d6cec.jpg'),
#  WindowsPath('datasets/flower_photos/flower_photos/daisy/10172379554_b296050f82_n.jpg'),
#  WindowsPath('datasets/flower_photos/flower_photos/daisy/10172567486_2748826a8b.jpg'),
#  WindowsPath('datasets/flower_photos/flower_photos/daisy/10172636503_21bededa75_n.jpg')]

# %%
image_count = len(list(data_dir.glob('*/*.jpg')))
print(image_count)
# Out:
# 3670

# %%
roses = list(data_dir.glob('roses/*'))
roses[:5]
# Out:
# [WindowsPath('datasets/flower_photos/flower_photos/roses/10090824183_d02c613f10_m.jpg'),
#  WindowsPath('datasets/flower_photos/flower_photos/roses/102501987_3cdb8e5394_n.jpg'),
#  WindowsPath('datasets/flower_photos/flower_photos/roses/10503217854_e66a804309.jpg'),
#  WindowsPath('datasets/flower_photos/flower_photos/roses/10894627425_ec76bbc757_n.jpg'),
#  WindowsPath('datasets/flower_photos/flower_photos/roses/110472418_87b6a3aa98_m.jpg')]

# %%
PIL.Image.open(str(roses[1]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x240>

# %%
tulips = list(data_dir.glob('tulips/*'))
PIL.Image.open(str(tulips[0]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x209>

# %%
flowers_images_dict = {
    'roses': list(data_dir.glob('roses/*')),
    'daisy': list(data_dir.glob('daisy/*')),
    'dandelion': list(data_dir.glob('dandelion/*')),
    'sunflowers': list(data_dir.glob('sunflowers/*')),
    'tulips': list(data_dir.glob('tulips/*')),
}

# %%
flowers_labels_dict = {
    'roses': 0,
    'daisy': 1,
    'dandelion': 2,
    'sunflowers': 3,
    'tulips': 4,
}

# %%
flowers_images_dict['roses'][:5]
# Out:
# [WindowsPath('datasets/flower_photos/flower_photos/roses/10090824183_d02c613f10_m.jpg'),
#  WindowsPath('datasets/flower_photos/flower_photos/roses/102501987_3cdb8e5394_n.jpg'),
#  WindowsPath('datasets/flower_photos/flower_photos/roses/10503217854_e66a804309.jpg'),
#  WindowsPath('datasets/flower_photos/flower_photos/roses/10894627425_ec76bbc757_n.jpg'),
#  WindowsPath('datasets/flower_photos/flower_photos/roses/110472418_87b6a3aa98_m.jpg')]

# %%
str(flowers_images_dict['roses'][0])
# Out:
# 'datasets\\flower_photos\\flower_photos\\roses\\10090824183_d02c613f10_m.jpg'

# %%
img = cv2.imread(str(flowers_images_dict['roses'][0]))
img.shape
# Out:
# (240, 179, 3)

# %%
cv2.resize(img,(180,180)).shape
# Out:
# (180, 180, 3)

# %%
X, y = [], []

for flower_name, images in flowers_images_dict.items():
    for image in images:
        img = cv2.imread(str(image))
        resized_img = cv2.resize(img,(180,180))
        X.append(resized_img)
        y.append(flowers_labels_dict[flower_name])

# %%
X = np.array(X)
y = np.array(y)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

# %%
X_train_scaled = X_train / 255
X_test_scaled = X_test / 255

# %%
num_classes = 5

model = Sequential([
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
              
model.fit(X_train_scaled, y_train, epochs=30)
# Out:
# Epoch 1/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 19s 170ms/step - accuracy: 0.4033 - loss: 1.4291
# Epoch 2/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 15s 175ms/step - accuracy: 0.5745 - loss: 1.0669
# Epoch 3/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 14s 165ms/step - accuracy: 0.6461 - loss: 0.8872
# Epoch 4/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 15s 172ms/step - accuracy: 0.7169 - loss: 0.7297
# Epoch 5/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 14s 165ms/step - accuracy: 0.8100 - loss: 0.5275
# Epoch 6/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 15s 172ms/step - accuracy: 0.8950 - loss: 0.3247
# Epoch 7/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 14s 168ms/step - accuracy: 0.9397 - loss: 0.1964
# Epoch 8/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 15s 170ms/step - accuracy: 0.9517 - loss: 0.1746
# Epoch 9/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 15s 175ms/step - accuracy: 0.9764 - loss: 0.0850
# Epoch 10/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 15s 173ms/step - accuracy: 0.9873 - loss: 0.0508
# Epoch 11/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 17s 192ms/step - accuracy: 0.9876 - loss: 0.0433
# Epoch 12/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 14s 161ms/step - accuracy: 0.9942 - loss: 0.0286
# Epoch 13/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 15s 177ms/step - accuracy: 0.9938 - loss: 0.0262
# Epoch 14/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 14s 166ms/step - accuracy: 0.9851 - loss: 0.0687
# Epoch 15/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 14s 162ms/step - accuracy: 0.9967 - loss: 0.0166
# Epoch 16/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 14s 162ms/step - accuracy: 0.9924 - loss: 0.0302
# Epoch 17/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 14s 162ms/step - accuracy: 0.9971 - loss: 0.0143
# Epoch 18/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 14s 162ms/step - accuracy: 0.9993 - loss: 0.0068
# Epoch 19/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 14s 162ms/step - accuracy: 0.9996 - loss: 0.0039
# Epoch 20/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 14s 164ms/step - accuracy: 0.9996 - loss: 0.0035
# Epoch 21/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 14s 165ms/step - accuracy: 0.9993 - loss: 0.0055
# Epoch 22/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 14s 166ms/step - accuracy: 0.9993 - loss: 0.0047
# Epoch 23/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 14s 168ms/step - accuracy: 0.9993 - loss: 0.0049
# Epoch 24/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 15s 171ms/step - accuracy: 0.9993 - loss: 0.0040
# Epoch 25/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 15s 175ms/step - accuracy: 0.9993 - loss: 0.0030
# Epoch 26/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 15s 172ms/step - accuracy: 0.9993 - loss: 0.0041
# Epoch 27/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 15s 170ms/step - accuracy: 0.9996 - loss: 0.0014
# Epoch 28/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 15s 171ms/step - accuracy: 0.9996 - loss: 0.0015
# Epoch 29/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 15s 171ms/step - accuracy: 0.9996 - loss: 0.0029
# Epoch 30/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 16s 183ms/step - accuracy: 0.9996 - loss: 0.0023

# %%
model.evaluate(X_test_scaled,y_test)
# Out:
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.6329 - loss: 2.9055
# [2.905463933944702, 0.6328976154327393]

# %%
predictions = model.predict(X_test_scaled)
predictions
# Out:
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step
# array([[  3.1092508 ,  28.415648  ,  -1.1033894 , -17.531418  ,
#          -8.859464  ],
#        [ 10.859955  ,  -0.6842073 ,  -1.5408701 ,  -5.519536  ,
#           3.4550345 ],
#        [ -1.0069536 ,   5.541557  ,  16.546366  , -13.016093  ,
#          -5.143532  ],
#        ...,
#        [  4.078386  ,  -0.9575256 , -11.118978  ,  11.3457365 ,
#          12.347916  ],
#        [  0.6317947 ,   0.71336544,   1.196678  ,  -3.161109  ,
#          -4.27425   ],
#        [  0.48971298, -13.874777  ,   2.7188962 ,   7.827672  ,
#           4.7223268 ]], shape=(918, 5), dtype=float32)

# %%
score = tf.nn.softmax(predictions[0])
np.argmax(score)
# Out:
# np.int64(1)

# %%
y_test[0]
# Out:
# np.int64(1)

# %%
data_augmentation = keras.Sequential([
    layers.RandomFlip("horizontal", input_shape=(180,180, 3)),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
])
# Out:
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\preprocessing\data_layer.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
plt.axis('off')
plt.imshow(X[0])

# %%
plt.axis('off')
plt.imshow(data_augmentation(X)[0].numpy().astype("uint8"))

# %%
num_classes = 5

model = Sequential([
  data_augmentation,
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
              
model.fit(X_train_scaled, y_train, epochs=30)
# Out:
# Epoch 1/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 27s 276ms/step - accuracy: 0.4426 - loss: 1.3020
# Epoch 2/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 24s 281ms/step - accuracy: 0.5930 - loss: 1.0295
# Epoch 3/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 21s 248ms/step - accuracy: 0.6537 - loss: 0.8896
# Epoch 4/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 20s 230ms/step - accuracy: 0.6864 - loss: 0.8356
# Epoch 5/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 20s 230ms/step - accuracy: 0.6962 - loss: 0.7951
# Epoch 6/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 20s 230ms/step - accuracy: 0.7031 - loss: 0.7846
# Epoch 7/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 21s 246ms/step - accuracy: 0.7235 - loss: 0.7337
# Epoch 8/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 21s 242ms/step - accuracy: 0.7326 - loss: 0.7007
# Epoch 9/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 20s 235ms/step - accuracy: 0.7424 - loss: 0.6665
# Epoch 10/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 20s 235ms/step - accuracy: 0.7475 - loss: 0.6427
# Epoch 11/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 20s 234ms/step - accuracy: 0.7573 - loss: 0.6145
# Epoch 12/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 20s 231ms/step - accuracy: 0.7689 - loss: 0.5919
# Epoch 13/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 20s 237ms/step - accuracy: 0.7903 - loss: 0.5553
# Epoch 14/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 20s 232ms/step - accuracy: 0.8005 - loss: 0.5284
# Epoch 15/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 20s 232ms/step - accuracy: 0.8041 - loss: 0.5205
# Epoch 16/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 20s 232ms/step - accuracy: 0.8078 - loss: 0.5066
# Epoch 17/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 20s 231ms/step - accuracy: 0.8165 - loss: 0.4909
# Epoch 18/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 20s 233ms/step - accuracy: 0.8379 - loss: 0.4326
# Epoch 19/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 20s 236ms/step - accuracy: 0.8416 - loss: 0.4177
# Epoch 20/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 21s 247ms/step - accuracy: 0.8525 - loss: 0.4064
# Epoch 21/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 21s 239ms/step - accuracy: 0.8470 - loss: 0.4176
# Epoch 22/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 21s 243ms/step - accuracy: 0.8557 - loss: 0.3851
# Epoch 23/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 21s 240ms/step - accuracy: 0.8565 - loss: 0.3863
# Epoch 24/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 20s 237ms/step - accuracy: 0.8699 - loss: 0.3546
# Epoch 25/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 20s 234ms/step - accuracy: 0.8768 - loss: 0.3362
# Epoch 26/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 255ms/step - accuracy: 0.8677 - loss: 0.3536
# Epoch 27/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 20s 235ms/step - accuracy: 0.8877 - loss: 0.3107
# Epoch 28/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 20s 234ms/step - accuracy: 0.8834 - loss: 0.3043
# Epoch 29/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 20s 233ms/step - accuracy: 0.8914 - loss: 0.2910
# Epoch 30/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 20s 234ms/step - accuracy: 0.9073 - loss: 0.2554

# %%
model.evaluate(X_test_scaled,y_test)
# Out:
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.7211 - loss: 0.9870
# [0.986990213394165, 0.7211328744888306]
