# %%
import tensorflow as tf
import pandas as pd
# Out:
# WARNING:tensorflow:From C:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv(r'C:/Users/HP/Downloads/Churn_Modelling.csv')

# %%
X = dataset.iloc[:, 3:13]
y = dataset.iloc[:, 13]

# %%
#Create dummy variables
geography=pd.get_dummies(X["Geography"],drop_first=True)
gender=pd.get_dummies(X['Gender'],drop_first=True)

# %%
## Concatenate the Data Frames
X=pd.concat([X,geography,gender],axis=1)

# %%
## Drop Unnecessary columns
X=X.drop(['Geography','Gender'],axis=1)

# %%
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LeakyReLU,PReLU,ELU
from keras.layers import Dropout

# %%
# Initialising the ANN
classifier = Sequential()
# Out:
# WARNING:tensorflow:From C:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
# Adding the input layer and the first hidden layer
classifier.add(Dense(units=6,kernel_initializer='he_uniform',activation='relu',input_dim=11))

# %%
# Adding the second hidden layer
classifier.add(Dense(units = 6, kernel_initializer = 'he_uniform',activation='relu'))

# %%
# Adding the output layer
classifier.add(Dense(units = 1, kernel_initializer = 'glorot_uniform', activation = 'sigmoid'))

# %%
# Compiling the ANN
classifier.compile(optimizer = 'Adamax', loss = 'binary_crossentropy', metrics = ['accuracy'])
# Out:
# WARNING:tensorflow:From C:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
# Fitting the ANN to the Training set
model_history=classifier.fit(X_train, y_train,validation_split=0.33, batch_size = 10, epochs = 100)
# Out:
# Epoch 1/100
# WARNING:tensorflow:From C:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 536/536 [==============================] - 4s 4ms/step - loss: 0.5221 - accuracy: 0.7860 - val_loss: 0.4961 - val_accuracy: 0.7955
# Epoch 2/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4754 - accuracy: 0.7959 - val_loss: 0.4774 - val_accuracy: 0.7955
# Epoch 3/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4614 - accuracy: 0.7972 - val_loss: 0.4684 - val_accuracy: 0.7955
# Epoch 4/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4532 - accuracy: 0.7979 - val_loss: 0.4620 - val_accuracy: 0.7955
# Epoch 5/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4475 - accuracy: 0.7994 - val_loss: 0.4568 - val_accuracy: 0.7967
# Epoch 6/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4431 - accuracy: 0.7992 - val_loss: 0.4527 - val_accuracy: 0.7993
# Epoch 7/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4397 - accuracy: 0.7994 - val_loss: 0.4496 - val_accuracy: 0.7989
# Epoch 8/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4368 - accuracy: 0.7994 - val_loss: 0.4464 - val_accuracy: 0.7993
# Epoch 9/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4344 - accuracy: 0.8024 - val_loss: 0.4439 - val_accuracy: 0.8005
# Epoch 10/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4321 - accuracy: 0.8039 - val_loss: 0.4420 - val_accuracy: 0.8012
# Epoch 11/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4303 - accuracy: 0.8048 - val_loss: 0.4398 - val_accuracy: 0.8008
# Epoch 12/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4284 - accuracy: 0.8054 - val_loss: 0.4382 - val_accuracy: 0.8008
# Epoch 13/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4266 - accuracy: 0.8059 - val_loss: 0.4365 - val_accuracy: 0.8023
# Epoch 14/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4250 - accuracy: 0.8059 - val_loss: 0.4351 - val_accuracy: 0.8058
# Epoch 15/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4235 - accuracy: 0.8072 - val_loss: 0.4338 - val_accuracy: 0.8092
# Epoch 16/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4220 - accuracy: 0.8074 - val_loss: 0.4325 - val_accuracy: 0.8095
# Epoch 17/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4206 - accuracy: 0.8078 - val_loss: 0.4315 - val_accuracy: 0.8080
# Epoch 18/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4193 - accuracy: 0.8093 - val_loss: 0.4304 - val_accuracy: 0.8095
# Epoch 19/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4180 - accuracy: 0.8100 - val_loss: 0.4291 - val_accuracy: 0.8107
# Epoch 20/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4166 - accuracy: 0.8113 - val_loss: 0.4279 - val_accuracy: 0.8107
# Epoch 21/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4152 - accuracy: 0.8108 - val_loss: 0.4266 - val_accuracy: 0.8118
# Epoch 22/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4137 - accuracy: 0.8123 - val_loss: 0.4254 - val_accuracy: 0.8126
# Epoch 23/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4123 - accuracy: 0.8125 - val_loss: 0.4245 - val_accuracy: 0.8137
# Epoch 24/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4111 - accuracy: 0.8136 - val_loss: 0.4235 - val_accuracy: 0.8145
# Epoch 25/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.4099 - accuracy: 0.8140 - val_loss: 0.4223 - val_accuracy: 0.8141
# Epoch 26/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4087 - accuracy: 0.8140 - val_loss: 0.4212 - val_accuracy: 0.8145
# Epoch 27/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4072 - accuracy: 0.8147 - val_loss: 0.4201 - val_accuracy: 0.8145
# Epoch 28/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4060 - accuracy: 0.8155 - val_loss: 0.4191 - val_accuracy: 0.8148
# Epoch 29/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4047 - accuracy: 0.8151 - val_loss: 0.4180 - val_accuracy: 0.8137
# Epoch 30/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4032 - accuracy: 0.8162 - val_loss: 0.4171 - val_accuracy: 0.8137
# Epoch 31/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4018 - accuracy: 0.8160 - val_loss: 0.4161 - val_accuracy: 0.8137
# Epoch 32/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4006 - accuracy: 0.8164 - val_loss: 0.4151 - val_accuracy: 0.8141
# Epoch 33/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3991 - accuracy: 0.8166 - val_loss: 0.4139 - val_accuracy: 0.8137
# Epoch 34/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3979 - accuracy: 0.8175 - val_loss: 0.4127 - val_accuracy: 0.8152
# Epoch 35/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3966 - accuracy: 0.8169 - val_loss: 0.4116 - val_accuracy: 0.8160
# Epoch 36/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3954 - accuracy: 0.8171 - val_loss: 0.4104 - val_accuracy: 0.8148
# Epoch 37/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3943 - accuracy: 0.8168 - val_loss: 0.4092 - val_accuracy: 0.8160
# Epoch 38/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3930 - accuracy: 0.8169 - val_loss: 0.4079 - val_accuracy: 0.8164
# Epoch 39/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3918 - accuracy: 0.8179 - val_loss: 0.4069 - val_accuracy: 0.8156
# Epoch 40/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3906 - accuracy: 0.8184 - val_loss: 0.4057 - val_accuracy: 0.8164
# Epoch 41/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3895 - accuracy: 0.8184 - val_loss: 0.4043 - val_accuracy: 0.8160
# Epoch 42/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3882 - accuracy: 0.8192 - val_loss: 0.4033 - val_accuracy: 0.8171
# Epoch 43/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3870 - accuracy: 0.8194 - val_loss: 0.4021 - val_accuracy: 0.8167
# Epoch 44/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3859 - accuracy: 0.8203 - val_loss: 0.4009 - val_accuracy: 0.8164
# Epoch 45/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3847 - accuracy: 0.8197 - val_loss: 0.4000 - val_accuracy: 0.8164
# Epoch 46/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3837 - accuracy: 0.8209 - val_loss: 0.3990 - val_accuracy: 0.8164
# Epoch 47/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3827 - accuracy: 0.8207 - val_loss: 0.3982 - val_accuracy: 0.8167
# Epoch 48/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3817 - accuracy: 0.8190 - val_loss: 0.3976 - val_accuracy: 0.8164
# Epoch 49/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3808 - accuracy: 0.8201 - val_loss: 0.3968 - val_accuracy: 0.8183
# Epoch 50/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3799 - accuracy: 0.8182 - val_loss: 0.3962 - val_accuracy: 0.8145
# Epoch 51/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3789 - accuracy: 0.8199 - val_loss: 0.3955 - val_accuracy: 0.8179
# Epoch 52/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3780 - accuracy: 0.8225 - val_loss: 0.3950 - val_accuracy: 0.8183
# Epoch 53/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3771 - accuracy: 0.8224 - val_loss: 0.3943 - val_accuracy: 0.8201
# Epoch 54/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3761 - accuracy: 0.8229 - val_loss: 0.3938 - val_accuracy: 0.8201
# Epoch 55/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3754 - accuracy: 0.8253 - val_loss: 0.3935 - val_accuracy: 0.8209
# Epoch 56/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3746 - accuracy: 0.8235 - val_loss: 0.3931 - val_accuracy: 0.8217
# Epoch 57/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3737 - accuracy: 0.8246 - val_loss: 0.3926 - val_accuracy: 0.8236
# Epoch 58/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3730 - accuracy: 0.8250 - val_loss: 0.3922 - val_accuracy: 0.8239
# Epoch 59/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3721 - accuracy: 0.8263 - val_loss: 0.3921 - val_accuracy: 0.8198
# Epoch 60/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3717 - accuracy: 0.8252 - val_loss: 0.3915 - val_accuracy: 0.8228
# Epoch 61/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3709 - accuracy: 0.8339 - val_loss: 0.3911 - val_accuracy: 0.8334
# Epoch 62/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3703 - accuracy: 0.8414 - val_loss: 0.3908 - val_accuracy: 0.8342
# Epoch 63/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3695 - accuracy: 0.8403 - val_loss: 0.3903 - val_accuracy: 0.8326
# Epoch 64/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3689 - accuracy: 0.8433 - val_loss: 0.3900 - val_accuracy: 0.8345
# Epoch 65/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3683 - accuracy: 0.8433 - val_loss: 0.3896 - val_accuracy: 0.8338
# Epoch 66/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3678 - accuracy: 0.8434 - val_loss: 0.3891 - val_accuracy: 0.8342
# Epoch 67/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3671 - accuracy: 0.8440 - val_loss: 0.3886 - val_accuracy: 0.8338
# Epoch 68/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3665 - accuracy: 0.8444 - val_loss: 0.3884 - val_accuracy: 0.8330
# Epoch 69/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3659 - accuracy: 0.8425 - val_loss: 0.3879 - val_accuracy: 0.8334
# Epoch 70/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3653 - accuracy: 0.8466 - val_loss: 0.3875 - val_accuracy: 0.8338
# Epoch 71/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3648 - accuracy: 0.8444 - val_loss: 0.3871 - val_accuracy: 0.8338
# Epoch 72/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3641 - accuracy: 0.8459 - val_loss: 0.3866 - val_accuracy: 0.8342
# Epoch 73/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3636 - accuracy: 0.8468 - val_loss: 0.3860 - val_accuracy: 0.8357
# Epoch 74/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3630 - accuracy: 0.8475 - val_loss: 0.3856 - val_accuracy: 0.8357
# Epoch 75/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3624 - accuracy: 0.8481 - val_loss: 0.3854 - val_accuracy: 0.8357
# Epoch 76/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3619 - accuracy: 0.8494 - val_loss: 0.3851 - val_accuracy: 0.8357
# Epoch 77/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3614 - accuracy: 0.8513 - val_loss: 0.3847 - val_accuracy: 0.8360
# Epoch 78/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3608 - accuracy: 0.8503 - val_loss: 0.3846 - val_accuracy: 0.8364
# Epoch 79/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3605 - accuracy: 0.8528 - val_loss: 0.3843 - val_accuracy: 0.8376
# Epoch 80/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3600 - accuracy: 0.8513 - val_loss: 0.3836 - val_accuracy: 0.8353
# Epoch 81/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3596 - accuracy: 0.8524 - val_loss: 0.3833 - val_accuracy: 0.8345
# Epoch 82/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3591 - accuracy: 0.8533 - val_loss: 0.3836 - val_accuracy: 0.8368
# Epoch 83/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3588 - accuracy: 0.8518 - val_loss: 0.3833 - val_accuracy: 0.8364
# Epoch 84/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3582 - accuracy: 0.8520 - val_loss: 0.3827 - val_accuracy: 0.8368
# Epoch 85/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3580 - accuracy: 0.8537 - val_loss: 0.3827 - val_accuracy: 0.8387
# Epoch 86/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3576 - accuracy: 0.8554 - val_loss: 0.3822 - val_accuracy: 0.8383
# Epoch 87/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3571 - accuracy: 0.8533 - val_loss: 0.3819 - val_accuracy: 0.8395
# Epoch 88/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3567 - accuracy: 0.8556 - val_loss: 0.3815 - val_accuracy: 0.8383
# Epoch 89/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3565 - accuracy: 0.8556 - val_loss: 0.3812 - val_accuracy: 0.8398
# Epoch 90/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3560 - accuracy: 0.8558 - val_loss: 0.3813 - val_accuracy: 0.8398
# Epoch 91/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3558 - accuracy: 0.8541 - val_loss: 0.3807 - val_accuracy: 0.8398
# Epoch 92/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3553 - accuracy: 0.8569 - val_loss: 0.3808 - val_accuracy: 0.8413
# Epoch 93/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3552 - accuracy: 0.8545 - val_loss: 0.3802 - val_accuracy: 0.8410
# Epoch 94/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3548 - accuracy: 0.8559 - val_loss: 0.3804 - val_accuracy: 0.8417
# Epoch 95/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3544 - accuracy: 0.8561 - val_loss: 0.3798 - val_accuracy: 0.8429
# Epoch 96/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3540 - accuracy: 0.8572 - val_loss: 0.3797 - val_accuracy: 0.8421
# Epoch 97/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3538 - accuracy: 0.8565 - val_loss: 0.3793 - val_accuracy: 0.8425
# Epoch 98/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3534 - accuracy: 0.8576 - val_loss: 0.3792 - val_accuracy: 0.8432
# Epoch 99/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3530 - accuracy: 0.8565 - val_loss: 0.3787 - val_accuracy: 0.8417
# Epoch 100/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3527 - accuracy: 0.8582 - val_loss: 0.3787 - val_accuracy: 0.8429

# %%
# list all data in history
print(model_history.history.keys())
# summarize history for accuracy
plt.plot(model_history.history['accuracy'])
plt.plot(model_history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
# summarize history for loss
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# Predicting the Test set results
y_pred = classifier.predict(X_test)
y_pred = (y_pred > 0.5)
# Out:
# 63/63 [==============================] - 0s 2ms/step

# %%
# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)

# %%
# Calculate the Accuracy
from sklearn.metrics import accuracy_score
score=accuracy_score(y_pred,y_test)

# %%
score
# Out:
# 0.853

# %%
import seaborn as sn

# %%
plt.figure(figsize=(10,7))
sn.heatmap(cm,annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(95.72222222222221, 0.5, 'Truth')

# %%
X.head()
# Out:
#    CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          619   42       2       0.00              1          1
# 1          608   41       1   83807.86              1          0
# 2          502   42       8  159660.80              3          1
# 3          699   39       1       0.00              2          0
# 4          850   43       2  125510.82              1          1
#
#    IsActiveMember  EstimatedSalary  Germany  Spain   Male
# 0               1        101348.88    False  False  False
# 1               1        112542.58    False   True  False
# 2               0        113931.57    False  False  False
# 3               0         93826.63    False  False  False
# 4               1         79084.10    False   True  False

# %%
y.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    0
# Name: Exited, dtype: int64
