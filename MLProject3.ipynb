# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\HP\Documents\data3.csv")
df
# Out:
#    Hours Studied  Exam Score
# 0              1          50
# 1              2          55
# 2              3          65
# 3              4          70
# 4              5          75
# 5              6          80
# 6              7          88
# 7              8          92

# %%
X=df[['Hours Studied']]
y=df[['Exam Score']]

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()

# %%
model.fit(X,y)
# Out:
# LinearRegression()

# %%
model.predict([[10]])
# Out:
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[105.20238095]])

# %%
model.coef_
# Out:
# array([[6.05952381]])

# %%
model.intercept_
# Out:
# array([44.60714286])

# %%
import matplotlib.pyplot as plt
plt.scatter(X,y)
plt.plot(X,model.predict(X))
plt.xlabel("Study Hours")
plt.ylabel("Score")
plt.show()

# %%
model.predict([[11]])
# Out:
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[111.26190476]])

# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\HP\Documents\data4.csv")
df
# Out:
#      size  bedrooms   age   price
# 0  1500.0       3.0  10.0  300000
# 1  1700.0       4.0   5.0  340000
# 2     NaN       3.0  20.0  280000
# 3  2000.0       NaN  15.0  360000
# 4  2100.0       4.0   NaN  400000
# 5     NaN       5.0   8.0  420000
# 6  2500.0       NaN  12.0  390000

# %%
df.isna().sum()
# Out:
# size        2
# bedrooms    2
# age         1
# price       0
# dtype: int64

# %%
df.columns
# Out:
# Index(['size', 'bedrooms', 'age', 'price'], dtype='object')

# %%
df['size']=df['size'].fillna(df['size'].mean())

# %%
df['bedrooms']=df['bedrooms'].fillna(df['bedrooms'].median())

# %%
df['age']=df['age'].fillna(df['age'].median())

# %%
df
# Out:
#      size  bedrooms   age   price
# 0  1500.0       3.0  10.0  300000
# 1  1700.0       4.0   5.0  340000
# 2  1960.0       3.0  20.0  280000
# 3  2000.0       4.0  15.0  360000
# 4  2100.0       4.0  11.0  400000
# 5  1960.0       5.0   8.0  420000
# 6  2500.0       4.0  12.0  390000

# %%
X=df[['size','bedrooms','age']]
y=df[['price']]

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(X,y)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([[   64.39000294, 49620.00717671, -2332.38420565]])

# %%
model.intercept_
# Out:
# array([65107.4409436])

# %%
model.predict([[1550,3,25]])
# Out:
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[255462.36188328]])

# %%
model.predict([[2000,3,2]])
# Out:
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[338082.69993429]])

# %%
model.predict([[2100,4,5]])
# Out:
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[387144.55478766]])

# %%
model.predict([[2050,3,10]])
# Out:
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[322643.12643592]])

# %%
model.predict([[1900,3,15]])
# Out:
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[301322.70496731]])
