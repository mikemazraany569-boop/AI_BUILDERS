# %%
import os

# Point directly to your Java
os.environ["JAVA_HOME"] = r"C:\Program Files\Java\jdk1.8.0_481"
os.environ["PATH"] = os.environ["JAVA_HOME"] + r"\bin;" + os.environ["PATH"]

from pyspark.sql import SparkSession

# Force local mode
spark = SparkSession.builder.master("local[*]").appName("HadoopTest").getOrCreate()

print("Spark started successfully")
